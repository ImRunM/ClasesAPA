# %% [markdown]
# ## Interfaz gráfica en python
# tkinter

# %%
import tkinter as tk

# %%
import tkinter.messagebox as msg

# %%
msg.askquestion?
# Out:
# Signature: msg.askquestion(title=None, message=None, **options)
# Docstring: Ask a question
# File:      c:\program files\python312\lib\tkinter\messagebox.py
# Type:      function

# %%
msg.askquestion()
