# %%
a = print(2,4)
# Out:
# 2 4

# %%
print(a)
# Out:
# None

# %% [markdown]
# Programación funcional > aquella programación que se basa en funciones, una función pura dado un número de argumentos da siempre el mismo resultado para esos argumentos. No existen variables.
#
# Todo en python son objetos. Todo lo contrario a la programacioón funcional. Pero hay programaión funcional en python.

# %%
r = range(4006**556) # ejecución perezosa, no almacena todo el rango

# %%
r[4006**251]
# Out:
# ...

# %%
r[4006**251:4006**251+10]
# Out:
# range(..., ...)

# %%
# Programación funcional en python
# Clases iterables
